# %%
from os import listdir
from os.path import isfile, join, exists
import pandas as pd
import io
import numpy as np
import re
import xlrd
from datetime import datetime

# %%
def pandas2tsv(df,path):
    base_path = "D:/Users/ldavid/Documents/Stock Combustible"
    sep = ','
    index = False
    header = True
    encoding = 'utf-8-sig'
    df.to_csv(base_path+path,
              index=index,
              sep=sep,
              header=header,
              encoding=encoding
              )
def get_fecha2(year,month):
    for i in range(len(list_of_months)):
        if i<9 and month==list_of_months[i]:
            fecha='01-'+ '0' + str(i+1) + '-' + year
            
        elif i>8 and month==list_of_months[i]:
            fecha='01-' + str(i+1) + '-' + year
                 
    return fecha

# %%
df = pd.read_excel('D:/Users/ldavid/Documents/Stock Combustible/Pendrives con data stock/Control de Stock/2004'+"/"+'resumen control stock 2004.xls',sheet_name='julio')

# %%
df
# Out:
#    Control Stock Informado MES DE        Unnamed: 1          JULIO  \
# 0                             NaN               NaN            NaN
# 1                             NaN               NaN  Electroandina
# 2                             NaN               NaN        Carbón
# 3                             NaN               NaN          [ton]
# 4                   Stock inicial         Informado          59683
# 5                        Ingresos         Informado         129928
# 6                         Consumo         Informado        68623.7
# 7                          Mermas         Informado          359.8
# 8                  Ventas/Compras         Informado              0
# 9                             NaN               NaN            NaN
# 10                    Stock final         Informado         120627
# 11                            NaN         Calculado         127585
# 12                            NaN  Dif.  Inf./Calc.       -6958.18
# ...

# %%
        listLines = []
        data={}
        columns=['Empresa','Tipo_combustible','Stock_inicial','Stock_final','Mermas','fecha']
        df2 = pd.DataFrame(data=data, columns=columns)
        
        
        df = df.rename(columns={'Control Stock Informado MES DE': 'col'})
        df = df.rename(columns={'JUNIO': 'Electroandina1'})
        df = df.rename(columns={'Unnamed: 3': 'Electroandina2'})
        df = df.rename(columns={'Unnamed: 4': 'Eldenor1'})
        df = df.rename(columns={'Unnamed: 5': 'Eldenor2'})
        df = df.rename(columns={'Unnamed: 6': 'Norgener1'})
        df = df.rename(columns={'Unnamed: 7': 'Norgener2'})
        df = df.rename(columns={'Unnamed: 8': 'Celta'})
        
        a=df.index[df['col']== 'Stock inicial'].tolist()
        b=df.index[df['col']== 'Stock final'].tolist()
        c=df.index[df['col']== 'Mermas'].tolist()

# %%
      
        df = pd.read_excel('D:/Users/ldavid/Documents/Stock Combustible/Pendrives con data stock/Control de Stock/2004'+"/"+'resumen control stock 2004.xls',sheet_name='diciembre')   
    
        listLines = []
        data={}
        columns=['Empresa','Tipo_combustible','Stock_inicial','Stock_final','Mermas','fecha']
        df2 = pd.DataFrame(data=data, columns=columns)
        
        
        df = df.rename(columns={'Control Stock Informado MES DE': 'col'})
        df = df.rename(columns={'DICIEMBRE': 'Electroandina1'})
        df = df.rename(columns={'Unnamed: 3': 'Electroandina2'})
        df = df.rename(columns={'Unnamed: 4': 'Eldenor1'})
        df = df.rename(columns={'Unnamed: 5': 'Eldenor2'})
        df = df.rename(columns={'Unnamed: 6': 'Norgener1'})
        df = df.rename(columns={'Unnamed: 7': 'Norgener2'})
        df = df.rename(columns={'Unnamed: 8': 'Celta'})
        
        a=df.index[df['col']== 'Stock inicial'].tolist()
        b=df.index[df['col']== 'Stock final'].tolist()
        c=df.index[df['col']== 'Mermas'].tolist()

            #Electroandina carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.Electroandina1[a[0]]],'Stock_final':[df.Electroandina1[b[0]]],'Tipo_combustible':[df.Electroandina1[a[0]-2]],'Mermas':[df.Electroandina1[c[0]]],'Empresa':[df.Electroandina1[a[0]-3]]})
        df2 = df2.append(df3)
        
            #Electroandina petcoke
        df3 = pd.DataFrame({'Stock_inicial':[df.Electroandina2[a[0]]],'Stock_final':[df.Electroandina2[b[0]]],'Tipo_combustible':[df.Electroandina2[a[0]-2]],'Mermas':[df.Electroandina2[c[0]]],'Empresa':[df.Electroandina1[a[0]-3]]})
        df2 = df2.append(df3)       
        
            #eldenor carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.Eldenor1[a[0]]],'Stock_final':[df.Eldenor1[b[0]]],'Tipo_combustible':[df.Eldenor1[a[0]-2]],'Mermas':[df.Eldenor1[c[0]]],'Empresa':[df.Eldenor1[a[0]-3]]})
        df2 = df2.append(df3)  
        
            #eldenor petcoke
        df3 = pd.DataFrame({'Stock_inicial':[df.Eldenor2[a[0]]],'Stock_final':[df.Eldenor2[b[0]]],'Tipo_combustible':[df.Eldenor2[a[0]-2]],'Mermas':[df.Eldenor2[c[0]]],'Empresa':[df.Eldenor1[a[0]-3]]})
        df2 = df2.append(df3) 
        
            #norgener carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.Norgener1[a[0]]],'Stock_final':[df.Norgener1[b[0]]],'Tipo_combustible':[df.Norgener1[a[0]-2]],'Mermas':[df.Norgener1[c[0]]],'Empresa':[df.Norgener1[a[0]-3]]})
        df2 = df2.append(df3)     
        
            #Norgener petcoke
        df3 = pd.DataFrame({'Stock_inicial':[df.Norgener2[a[0]]],'Stock_final':[df.Norgener2[b[0]]],'Tipo_combustible':[df.Norgener2[a[0]-2]],'Mermas':[df.Norgener2[c[0]]],'Empresa':[df.Norgener1[a[0]-3]]})
        df2 = df2.append(df3)   
        
            #celta carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.Celta[a[0]]],'Stock_final':[df.Celta[b[0]]],'Tipo_combustible':[df.Celta[a[0]-2]],'Mermas':[df.Celta[c[0]]],'Empresa':[df.Celta[a[0]-3]]})
        df2 = df2.append(df3)       
        
        
        df2['fecha']='01-12-2004'
        
        listLines.append(df2)
        output = pd.concat(listLines)
        output_path = "Stock combustible 2004 diciembre.csv"
        pandas2tsv(output,output_path)

# %%
df.Norgener1[a[0]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-27e1dcca56a0> in <module>
# ----> 1 df.Norgener1[a[0]]
#
# D:\ProgramData\Anaconda3\envs\tf\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Norgener1'

# %%
a
# Out:
# [4]
