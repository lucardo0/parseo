# %%
from os import listdir
from os.path import isfile, join, exists
import pandas as pd
import io
import numpy as np
import re
import xlrd
from datetime import datetime

# %%
def pandas2tsv(df,path):
    base_path = "D:/Users/ldavid/Documents/Stock Combustible"
    sep = ','
    index = False
    header = True
    encoding = 'utf-8-sig'
    df.to_csv(base_path+path,
              index=index,
              sep=sep,
              header=header,
              encoding=encoding
              )
def get_fecha2(year,month):
    for i in range(len(list_of_months)):
        if i<9 and month==list_of_months[i]:
            fecha='01-'+ '0' + str(i+1) + '-' + year
            
        elif i>8 and month==list_of_months[i]:
            fecha='01-' + str(i+1) + '-' + year
                 
    return fecha

# %%
df = pd.read_excel('D:/Users/ldavid/Documents/Stock Combustible/Pendrives con data stock/Control de Stock/2002'+"/"+'control stock JUNIO 2002.xls',sheet_name='Stock Informado-Teórico')

# %%
df
# Out:
#           Comparación entre Stock Informado y Teórico     Edelnor1  \
# 0                                                 NaN          NaN
# 1                                                 NaN      EDELNOR
# 2                                                 NaN      Carbón
# 3                                                 NaN        [ton]
# 4                Stock Teórico calculado desde/hasta:   1-30 JUNIO
# 5                             Consumo teórico (JUNIO)      29915.3
# 6                                                 NaN          NaN
# 7              Stock Informado calculado desde/hasta:   1-30 JUNIO
# 8                Stock Disponible Informado (31 MAYO)       103374
# 9                       Compras comprometidas (JUNIO)          NaN
# 10                          Stock informado (1 JULIO)      75358.5
# 11              Consumo informado (calculado) (JUNIO)      28015.5
# 12                          Consumo informado (JUNIO)      28015.5
# ...

# %%
#df = df.rename(columns={'Comparación entre stock Informado y Teorico': 'col'})
df = df.rename(columns={'Unnamed: 1': 'Edelnor1'})
df = df.rename(columns={'Unnamed: 2': 'Edelnor2'})
df = df.rename(columns={'Unnamed: 3': 'Celta'})
df = df.rename(columns={'Unnamed: 4': 'Electroandina'})
df = df.rename(columns={'Unnamed: 5': 'Norgener'})
        
a=df.index[df['Comparación entre stock informado y Teorico'] == 'Stock Final'].tolist()

# %%
            #Eldenor carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,1]],'Stock_final':[df.iloc[10,1]],'Tipo_combustible':[df.iloc[2,1]],'Mermas':[0],'Empresa':[df.iloc[1,1]]})
        df2 = df2.append(df3)
            #Eldenor Petcoke
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,2]],'Stock_final':[df.iloc[10,2]],'Tipo_combustible':[df.iloc[2,2]],'Mermas':[0],'Empresa':[df.iloc[1,1]]})
        df2 = df2.append(df3)
        
            #Celta Carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,3]],'Stock_final':[df.iloc[10,3]],'Tipo_combustible':[df.iloc[2,3]],'Mermas':[0],'Empresa':[df.iloc[1,3]]})
        df2 = df2.append(df3)
        
            #Electroandina Carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,4]],'Stock_final':[df.iloc[10,4]],'Tipo_combustible':[df.iloc[2,4]],'Mermas':[0],'Empresa':[df.iloc[1,4]]})
        df2 = df2.append(df3)        

            #Norgener Carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,5]],'Stock_final':[df.iloc[10,5]],'Tipo_combustible':[df.iloc[2,5]],'Mermas':[0],'Empresa':[df.iloc[1,5]]})
        df2 = df2.append(df3)   
        
        #-------------------------------------------------------------
        
        #Eldenor diesel
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,1]],'Stock_final':[df.Edelnor1[a[0]]],'Tipo_combustible':[df.iloc[23,1]],'Mermas':[0],'Empresa':[df.iloc[22,1]]})
        df2 = df2.append(df3)         
        #Eldenor oil
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,2]],'Stock_final':[df.Edelnor2[a[0]]],'Tipo_combustible':[df.iloc[23,2]],'Mermas':[0],'Empresa':[df.iloc[22,1]]})
        df2 = df2.append(df3)     
        
        #Celta diesel
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,3]],'Stock_final':[df.Celta[a[0]]],'Tipo_combustible':[df.iloc[23,3]],'Mermas':[0],'Empresa':[df.iloc[22,3]]})
        df2 = df2.append(df3)   
        
        #Electroandina diesel
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,4]],'Stock_final':[df.Electroandina[a[0]]],'Tipo_combustible':[df.iloc[23,4]],'Mermas':[0],'Empresa':[df.iloc[22,4]]})
        df2 = df2.append(df3)   
        #Electroandina oil
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,5]],'Stock_final':[df.Norgener[a[0]]],'Tipo_combustible':[df.iloc[23,5]],'Mermas':[0],'Empresa':[df.iloc[22,4]]})
        df2 = df2.append(df3)

# %%
        listLines = []
        data={}
        columns=['Empresa','Tipo_combustible','Stock_inicial','Stock_final','Mermas','fecha']
        df2 = pd.DataFrame(data=data, columns=columns)
        df = pd.read_excel('D:/Users/ldavid/Documents/Stock Combustible/Pendrives con data stock/Control de Stock/2003'+"/"+'control stock NOVIEMBRE 2003.xls',sheet_name='Stock Informado-Teórico')
        
        #df = df.rename(columns={'Comparación entre stock Informado y Teorico': 'col'})
        df = df.rename(columns={'Unnamed: 1': 'Edelnor1'})
        df = df.rename(columns={'Unnamed: 2': 'Edelnor2'})
        df = df.rename(columns={'Unnamed: 3': 'Celta'})
        df = df.rename(columns={'Unnamed: 4': 'Electroandina'})
        df = df.rename(columns={'Unnamed: 5': 'Norgener'})
        
        a=df.index[df['Comparación entre Stock Informado y Teórico']== 'Stock Final'].tolist()

            #Eldenor carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,1]],'Stock_final':[df.iloc[10,1]],'Tipo_combustible':[df.iloc[2,1]],'Mermas':[0],'Empresa':[df.iloc[1,1]]})
        df2 = df2.append(df3)
            #Eldenor Petcoke
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,2]],'Stock_final':[df.iloc[10,2]],'Tipo_combustible':[df.iloc[2,2]],'Mermas':[0],'Empresa':[df.iloc[1,1]]})
        df2 = df2.append(df3)
        
            #Celta Carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,3]],'Stock_final':[df.iloc[10,3]],'Tipo_combustible':[df.iloc[2,3]],'Mermas':[0],'Empresa':[df.iloc[1,3]]})
        df2 = df2.append(df3)
        
            #Electroandina Carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,4]],'Stock_final':[df.iloc[10,4]],'Tipo_combustible':[df.iloc[2,4]],'Mermas':[0],'Empresa':[df.iloc[1,4]]})
        df2 = df2.append(df3)        

            #Norgener Carbón
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[8,5]],'Stock_final':[df.iloc[10,5]],'Tipo_combustible':[df.iloc[2,5]],'Mermas':[0],'Empresa':[df.iloc[1,5]]})
        df2 = df2.append(df3)   
        
        #-------------------------------------------------------------
        
        #Eldenor diesel
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,1]],'Stock_final':[df.Edelnor1[a[0]]],'Tipo_combustible':[df.iloc[23,1]],'Mermas':[0],'Empresa':[df.iloc[22,1]]})
        df2 = df2.append(df3)         
        #Eldenor oil
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,2]],'Stock_final':[df.Edelnor2[a[0]]],'Tipo_combustible':[df.iloc[23,2]],'Mermas':[0],'Empresa':[df.iloc[22,1]]})
        df2 = df2.append(df3)     
        
        #Celta diesel
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,3]],'Stock_final':[df.Celta[a[0]]],'Tipo_combustible':[df.iloc[23,3]],'Mermas':[0],'Empresa':[df.iloc[22,3]]})
        df2 = df2.append(df3)   
        
        #Electroandina diesel
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,4]],'Stock_final':[df.Electroandina[a[0]]],'Tipo_combustible':[df.iloc[23,4]],'Mermas':[0],'Empresa':[df.iloc[22,4]]})
        df2 = df2.append(df3)   
        #Electroandina oil
        df3 = pd.DataFrame({'Stock_inicial':[df.iloc[29,5]],'Stock_final':[df.Norgener[a[0]]],'Tipo_combustible':[df.iloc[23,5]],'Mermas':[0],'Empresa':[df.iloc[22,4]]})
        df2 = df2.append(df3)  
        
        df2['fecha']='01-11-2003'
        
        listLines.append(df2)
        output = pd.concat(listLines)
        output_path = "Stock combustible 2003 nov.csv"
        pandas2tsv(output,output_path)
